# %% [markdown]
# <a href="https://colab.research.google.com/github/ummmu21/ummu/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = "/stocks.csv"

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#     Ticker        Date        Open        High         Low       Close  \
# 0     AAPL  2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1     AAPL  2023-02-08  153.880005  154.580002  151.169998  151.919998
# 2     AAPL  2023-02-09  153.779999  154.330002  150.419998  150.869995
# 3     AAPL  2023-02-10  149.460007  151.339996  149.220001  151.009995
# 4     AAPL  2023-02-13  150.949997  154.259995  150.919998  153.850006
# ..     ...         ...         ...         ...         ...         ...
# 243   GOOG  2023-05-01  107.720001  108.680000  107.500000  107.709999
# 244   GOOG  2023-05-02  107.660004  107.730003  104.500000  105.980003
# 245   GOOG  2023-05-03  106.220001  108.129997  105.620003  106.120003
# 246   GOOG  2023-05-04  106.160004  106.300003  104.699997  105.209999
# 247   GOOG  2023-05-05  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close    Volume
# 0    154.414230  83322600
# 1    151.688400  64120100
# 2    150.639999  56007100
# ...

# %%
data.head(10)
# Out:
#   Ticker        Date        Open        High         Low       Close  \
# 0   AAPL  2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1   AAPL  2023-02-08  153.880005  154.580002  151.169998  151.919998
# 2   AAPL  2023-02-09  153.779999  154.330002  150.419998  150.869995
# 3   AAPL  2023-02-10  149.460007  151.339996  149.220001  151.009995
# 4   AAPL  2023-02-13  150.949997  154.259995  150.919998  153.850006
# 5   AAPL  2023-02-14  152.119995  153.770004  150.860001  153.199997
# 6   AAPL  2023-02-15  153.110001  155.500000  152.880005  155.330002
# 7   AAPL  2023-02-16  153.509995  156.330002  153.350006  153.710007
# 8   AAPL  2023-02-17  152.350006  153.000000  150.850006  152.550003
# 9   AAPL  2023-02-21  150.199997  151.300003  148.410004  148.479996
#
#     Adj Close    Volume
# 0  154.414230  83322600
# 1  151.688400  64120100
# 2  150.639999  56007100
# 3  151.009995  57450700
# 4  153.850006  62199000
# 5  153.199997  61707600
# 6  155.330002  65573800
# ...

# %%
print(data.dtypes)
# Out:
# Ticker        object
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
datanoid=data.drop(data.columns[1],axis=1)

# %%
datanoid
# Out:
#     Ticker        Open        High         Low       Close   Adj Close  \
# 0     AAPL  150.639999  155.229996  150.639999  154.649994  154.414230
# 1     AAPL  153.880005  154.580002  151.169998  151.919998  151.688400
# 2     AAPL  153.779999  154.330002  150.419998  150.869995  150.639999
# 3     AAPL  149.460007  151.339996  149.220001  151.009995  151.009995
# 4     AAPL  150.949997  154.259995  150.919998  153.850006  153.850006
# ..     ...         ...         ...         ...         ...         ...
# 243   GOOG  107.720001  108.680000  107.500000  107.709999  107.709999
# 244   GOOG  107.660004  107.730003  104.500000  105.980003  105.980003
# 245   GOOG  106.220001  108.129997  105.620003  106.120003  106.120003
# 246   GOOG  106.160004  106.300003  104.699997  105.209999  105.209999
# 247   GOOG  105.320000  106.440002  104.738998  106.214996  106.214996
#
#        Volume
# 0    83322600
# 1    64120100
# 2    56007100
# 3    57450700
# 4    62199000
# ..        ...
# ...

# %%
data.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  248.000000  248.000000  248.000000  248.000000  248.000000
# mean   215.252093  217.919662  212.697452  215.381674  215.362697
# std     91.691315   92.863023   90.147881   91.461989   91.454750
# min     89.540001   90.129997   88.860001   89.349998   89.349998
# 25%    135.235004  137.440004  134.822495  136.347498  136.347498
# 50%    208.764999  212.614998  208.184998  209.920006  209.920006
# 75%    304.177505  307.565002  295.437500  303.942505  303.942505
# max    372.410004  373.829987  361.739990  366.829987  366.829987
#
#              Volume
# count  2.480000e+02
# mean   3.208210e+07
# std    2.233590e+07
# min    2.657900e+06
# 25%    1.714180e+07
# 50%    2.734000e+07
# 75%    4.771772e+07
# max    1.133164e+08

# %%
data.loc[:,"Open":].corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999626  0.999650  0.999176   0.999173 -0.547741
# High       0.999626  1.000000  0.999654  0.999644   0.999640 -0.546175
# Low        0.999650  0.999654  1.000000  0.999663   0.999661 -0.544590
# Close      0.999176  0.999644  0.999663  1.000000   0.999999 -0.544194
# Adj Close  0.999173  0.999640  0.999661  0.999999   1.000000 -0.544370
# Volume    -0.547741 -0.546175 -0.544590 -0.544194  -0.544370  1.000000

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='High', y='Low', s=32, alpha=1)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-048e679a-0a5f-43d6-9245-414adf902e3a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-048e679a-0a5f-43d6-9245-414adf902e3a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "saham"
# Out:
# ...
# ref                                                          title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# muamkh/ihsgstockdata                                         Dataset Saham Indonesia / Indonesia Stock Dataset  328MB  2023-01-08 19:26:36           2519         60  0.8235294
# tiwill/saham-idx                                             Pergerakan Saham di Bursa Efek Indonesia            30MB  2024-03-01 04:54:25           2675         76  0.8235294
# agungpambudi/dataset-saham-bursa-efek                        Dataset Saham Bursa Efek                           119KB  2022-08-24 17:56:39            481         13  0.9411765
# ...

# %%
# !kaggle datasets download -d AmirMotefaker/Stock-Market-Analysis-Data
# Out:
# ...
#   0% 0.00/6.00k [00:00<?, ?B/s]
# 100% 6.00k/6.00k [00:00<00:00, 9.48MB/s]

# %%
# !unzip /content/Stock-Market-Analysis-Data.zip
# Out:
# Archive:  /content/Stock-Market-Analysis-Data.zip
#   inflating: stocks.csv

# %%
pd.read_csv('/content/stocks.csv')
# Out:
#     Ticker        Date        Open        High         Low       Close  \
# 0     AAPL  2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1     AAPL  2023-02-08  153.880005  154.580002  151.169998  151.919998
# 2     AAPL  2023-02-09  153.779999  154.330002  150.419998  150.869995
# 3     AAPL  2023-02-10  149.460007  151.339996  149.220001  151.009995
# 4     AAPL  2023-02-13  150.949997  154.259995  150.919998  153.850006
# ..     ...         ...         ...         ...         ...         ...
# 243   GOOG  2023-05-01  107.720001  108.680000  107.500000  107.709999
# 244   GOOG  2023-05-02  107.660004  107.730003  104.500000  105.980003
# 245   GOOG  2023-05-03  106.220001  108.129997  105.620003  106.120003
# 246   GOOG  2023-05-04  106.160004  106.300003  104.699997  105.209999
# 247   GOOG  2023-05-05  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close    Volume
# 0    154.414230  83322600
# 1    151.688400  64120100
# 2    150.639999  56007100
# ...
